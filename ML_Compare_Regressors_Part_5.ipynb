# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
# Ajuni Sohota
#
# In Part 5, several ML algorithms will be compared for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## **2. Load the data set**

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2023-10-16 20:44:21--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2023-10-16 20:44:22--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8003::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: 'acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2'
#
# acetylcholinesteras 100%[===================>]   7.98M  31.0MB/s    in 0.3s
#
# 2023-10-16 20:44:23 (31.0 MB/s) - 'acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2' saved [8363909/8363909]

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████████████████████████████████| 42/42 [12:55:58<00:00, 1108.54s/it]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|███████████████████████████████████████████| 42/42 [18:54<00:00, 27.01s/it]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                        Adjusted R-Squared  \
# Model
# GaussianProcessRegressor                             0.86
# DecisionTreeRegressor                                0.86
# ExtraTreeRegressor                                   0.86
# ExtraTreesRegressor                                  0.86
# RandomForestRegressor                                0.82
# XGBRegressor                                         0.82
# BaggingRegressor                                     0.80
# MLPRegressor                                         0.76
# HistGradientBoostingRegressor                        0.67
# LGBMRegressor                                        0.65
# KNeighborsRegressor                                  0.63
# SVR                                                  0.56
# NuSVR                                                0.55
# GradientBoostingRegressor                            0.44
# Ridge                                                0.31
# LassoCV                                              0.30
# ElasticNetCV                                         0.30
# RidgeCV                                              0.30
# LassoLarsCV                                          0.30
# LassoLarsIC                                          0.30
# SGDRegressor                                         0.30
# BayesianRidge                                        0.29
# HuberRegressor                                       0.29
# LinearRegression                                     0.29
# TransformedTargetRegressor                           0.29
# LinearSVR                                            0.27
# PoissonRegressor                                     0.25
# AdaBoostRegressor                                    0.20
# OrthogonalMatchingPursuitCV                          0.20
# OrthogonalMatchingPursuit                            0.20
# TweedieRegressor                                     0.19
# GammaRegressor                                       0.19
# LarsCV                                               0.13
# Lars                                                 0.13
# LassoLars                                           -0.04
# ElasticNet                                          -0.04
# DummyRegressor                                      -0.04
# Lasso                                               -0.04
# QuantileRegressor                                   -0.05
# PassiveAggressiveRegressor                          -0.17
# KernelRidge                                        -14.25
# RANSACRegressor               -41740990194740598145024.00
#
#                                                 R-Squared            RMSE  \
# Model
# GaussianProcessRegressor                             0.86            0.57
# DecisionTreeRegressor                                0.86            0.57
# ExtraTreeRegressor                                   0.86            0.57
# ExtraTreesRegressor                                  0.86            0.57
# RandomForestRegressor                                0.83            0.64
# XGBRegressor                                         0.83            0.65
# BaggingRegressor                                     0.81            0.67
# MLPRegressor                                         0.77            0.75
# HistGradientBoostingRegressor                        0.69            0.87
# LGBMRegressor                                        0.67            0.90
# KNeighborsRegressor                                  0.65            0.92
# SVR                                                  0.58            1.01
# NuSVR                                                0.57            1.02
# GradientBoostingRegressor                            0.46            1.14
# Ridge                                                0.33            1.27
# LassoCV                                              0.33            1.27
# ElasticNetCV                                         0.33            1.27
# RidgeCV                                              0.33            1.27
# LassoLarsCV                                          0.33            1.27
# LassoLarsIC                                          0.32            1.28
# SGDRegressor                                         0.32            1.28
# BayesianRidge                                        0.32            1.28
# HuberRegressor                                       0.31            1.29
# LinearRegression                                     0.31            1.29
# TransformedTargetRegressor                           0.31            1.29
# LinearSVR                                            0.30            1.30
# PoissonRegressor                                     0.28            1.32
# AdaBoostRegressor                                    0.23            1.36
# OrthogonalMatchingPursuitCV                          0.23            1.37
# OrthogonalMatchingPursuit                            0.23            1.37
# TweedieRegressor                                     0.22            1.37
# GammaRegressor                                       0.22            1.37
# LarsCV                                               0.16            1.42
# Lars                                                 0.16            1.42
# LassoLars                                            0.00            1.55
# ElasticNet                                           0.00            1.55
# DummyRegressor                                       0.00            1.55
# Lasso                                                0.00            1.55
# QuantileRegressor                                   -0.01            1.56
# PassiveAggressiveRegressor                          -0.13            1.65
# KernelRidge                                        -13.70            5.95
# RANSACRegressor               -40218083228913837801472.00 311338209515.65
#
#                                Time Taken
# Model
# GaussianProcessRegressor             2.84
# DecisionTreeRegressor                0.06
# ExtraTreeRegressor                   0.06
# ExtraTreesRegressor                  3.93
# RandomForestRegressor                3.22
# XGBRegressor                         0.32
# BaggingRegressor                     0.34
# MLPRegressor                         4.64
# HistGradientBoostingRegressor        1.74
# LGBMRegressor                        0.51
# KNeighborsRegressor                  0.11
# SVR                                  2.51
# NuSVR                                1.77
# GradientBoostingRegressor            1.00
# Ridge                                0.02
# LassoCV                              1.91
# ElasticNetCV                         1.80
# RidgeCV                              0.13
# LassoLarsCV                          0.17
# LassoLarsIC                          0.15
# SGDRegressor                         0.06
# BayesianRidge                        0.15
# HuberRegressor                       0.19
# LinearRegression                     0.12
# TransformedTargetRegressor           0.10
# LinearSVR                            0.37
# PoissonRegressor                     0.06
# AdaBoostRegressor                    0.45
# OrthogonalMatchingPursuitCV          0.06
# OrthogonalMatchingPursuit            0.02
# TweedieRegressor                     0.04
# GammaRegressor                       0.03
# LarsCV                               0.16
# Lars                                 0.04
# LassoLars                            0.02
# ElasticNet                           0.02
# DummyRegressor                       0.01
# Lasso                                0.02
# QuantileRegressor                46527.51
# PassiveAggressiveRegressor           0.03
# KernelRidge                          0.52
# RANSACRegressor                      1.29

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                        Adjusted R-Squared  \
# Model
# HistGradientBoostingRegressor                        0.46
# RandomForestRegressor                                0.44
# LGBMRegressor                                        0.44
# XGBRegressor                                         0.44
# BaggingRegressor                                     0.41
# NuSVR                                                0.39
# SVR                                                  0.39
# KNeighborsRegressor                                  0.37
# MLPRegressor                                         0.36
# GradientBoostingRegressor                            0.33
# ExtraTreesRegressor                                  0.22
# DecisionTreeRegressor                                0.20
# Ridge                                                0.20
# RidgeCV                                              0.20
# ElasticNetCV                                         0.20
# LassoCV                                              0.20
# ExtraTreeRegressor                                   0.20
# LassoLarsCV                                          0.20
# LassoLarsIC                                          0.20
# SGDRegressor                                         0.19
# BayesianRidge                                        0.19
# LinearRegression                                     0.19
# TransformedTargetRegressor                           0.19
# HuberRegressor                                       0.19
# LinearSVR                                            0.16
# PoissonRegressor                                     0.16
# OrthogonalMatchingPursuit                            0.11
# OrthogonalMatchingPursuitCV                          0.11
# GammaRegressor                                       0.08
# TweedieRegressor                                     0.08
# AdaBoostRegressor                                    0.07
# LarsCV                                               0.02
# Lars                                                -0.02
# ElasticNet                                          -0.17
# DummyRegressor                                      -0.17
# LassoLars                                           -0.17
# Lasso                                               -0.17
# QuantileRegressor                                   -0.19
# PassiveAggressiveRegressor                          -0.42
# GaussianProcessRegressor                            -6.02
# KernelRidge                                        -16.36
# RANSACRegressor               -49714589564554153295872.00
#
#                                                 R-Squared            RMSE  \
# Model
# HistGradientBoostingRegressor                        0.54            1.06
# RandomForestRegressor                                0.52            1.08
# LGBMRegressor                                        0.52            1.08
# XGBRegressor                                         0.52            1.08
# BaggingRegressor                                     0.49            1.11
# NuSVR                                                0.48            1.12
# SVR                                                  0.48            1.12
# KNeighborsRegressor                                  0.46            1.14
# MLPRegressor                                         0.45            1.15
# GradientBoostingRegressor                            0.42            1.18
# ExtraTreesRegressor                                  0.34            1.27
# DecisionTreeRegressor                                0.32            1.28
# Ridge                                                0.32            1.28
# RidgeCV                                              0.32            1.28
# ElasticNetCV                                         0.32            1.28
# LassoCV                                              0.32            1.28
# ExtraTreeRegressor                                   0.32            1.29
# LassoLarsCV                                          0.31            1.29
# LassoLarsIC                                          0.31            1.29
# SGDRegressor                                         0.31            1.29
# BayesianRidge                                        0.31            1.29
# LinearRegression                                     0.31            1.29
# TransformedTargetRegressor                           0.31            1.29
# HuberRegressor                                       0.31            1.29
# LinearSVR                                            0.28            1.32
# PoissonRegressor                                     0.28            1.32
# OrthogonalMatchingPursuit                            0.24            1.36
# OrthogonalMatchingPursuitCV                          0.24            1.36
# GammaRegressor                                       0.22            1.37
# TweedieRegressor                                     0.22            1.38
# AdaBoostRegressor                                    0.21            1.38
# LarsCV                                               0.16            1.42
# Lars                                                 0.13            1.45
# ElasticNet                                          -0.00            1.55
# DummyRegressor                                      -0.00            1.55
# LassoLars                                           -0.00            1.55
# Lasso                                               -0.00            1.55
# QuantileRegressor                                   -0.02            1.57
# PassiveAggressiveRegressor                          -0.22            1.71
# GaussianProcessRegressor                            -4.99            3.80
# KernelRidge                                        -13.82            5.98
# RANSACRegressor               -42453503455445500559360.00 320008120598.41
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        1.78
# RandomForestRegressor                3.00
# LGBMRegressor                        0.49
# XGBRegressor                         0.31
# BaggingRegressor                     0.32
# NuSVR                                1.01
# SVR                                  1.38
# KNeighborsRegressor                  0.04
# MLPRegressor                         4.89
# GradientBoostingRegressor            0.99
# ExtraTreesRegressor                  3.95
# DecisionTreeRegressor                0.06
# Ridge                                0.02
# RidgeCV                              0.14
# ElasticNetCV                         1.84
# LassoCV                              1.86
# ExtraTreeRegressor                   0.06
# LassoLarsCV                          0.18
# LassoLarsIC                          0.14
# SGDRegressor                         0.05
# BayesianRidge                        0.12
# LinearRegression                     0.10
# TransformedTargetRegressor           0.10
# HuberRegressor                       0.25
# LinearSVR                            0.34
# PoissonRegressor                     0.08
# OrthogonalMatchingPursuit            0.02
# OrthogonalMatchingPursuitCV          0.07
# GammaRegressor                       0.04
# TweedieRegressor                     0.03
# AdaBoostRegressor                    0.41
# LarsCV                               0.16
# Lars                                 0.07
# ElasticNet                           0.01
# DummyRegressor                       0.01
# LassoLars                            0.02
# Lasso                                0.02
# QuantileRegressor                 1105.77
# PassiveAggressiveRegressor           0.03
# GaussianProcessRegressor             1.93
# KernelRidge                          0.51
# RANSACRegressor                      1.64

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
